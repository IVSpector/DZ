# %%
documents = [
{'type': 'passport', 'number': '2207 876234', 'name': 'Василий Гупкин'},
{'type': 'invoice', 'number': '11-2', 'name': 'Геннадий Покемонов'},
{'type': 'insurance', 'number': '10006', 'name': 'Аристарх Павлов'}
]


directories = {
'1': ['2207 876234', '11-2'],
'2': ['10006'],
'3': []
}


def true_number():
    number_doc = input('Введите номер документа: ')
    for element in documents:
        if number_doc in element['number']:
            return number_doc
    print('Документ не найден в базе.')
    return 

def true_shelf():
    number_shelf = input('Введите номер полки: ')
    if number_shelf in directories:
        print(f'Такая полка уже существует. Текущий перечень полок: {",".join(a)}')
        return
    return number_shelf
 
def empty_shelf():
    number_shelf = input('Введите номер полки: ')
    if directories.get(str(number_shelf)) == []:
        return number_polka
    elif directories.get(str(number_shelf)) is None:
        print ('Такой полки не существует.')
        return 
    else:
        print(f'На полке есть документа, удалите их перед удалением полки. Текущий перечень полок: {",".join(a)}')
        return 



def product_owner():
    
    number_doc = true_number()
    if number_doc is None:
        return
    
    for element in documents:
        if element['number'] == number_doc:
            name_owner = element['name'] 
    print(f'Владелец документа: {name_owner}')        
    return 


def search_shelf():
    
    number_doc = true_number()
    if number_doc is None:
        return
    
    for element in directories:
        if number_doc in directories[element]:
            print (f'Документ хранится на полке: {element}')
            return 

        
def show_all():
    
    for element in documents:
        for number in directories:
            if element["number"] in directories[number]:
                print (f'№ {element["number"]}, тип: {element["type"]}, владелец: {element["name"]}, полка хранения: {number}')
    
def as_func():
    
    number_shelf = true_shelf()
    if number_shelf is None:
        return
    directories[number_shelf] = ""
    a = list(directories.keys())
    print (f'Полка добавлена. Текущий перечень полок: {",".join(a)}')
    return 

def ds_func():
    number_shelf = empty_shelf()
    if number_shelf is None:
        return
    del directories[number_shelf]
    a = list(directories.keys())
    print (f'Полка удалена. Текущий перечень полок: {",".join(a)}')
    return 


data = {
    'p': product_owner ,
    's': search_shelf ,
    'l': show_all ,
    'as': as_func ,
    'ds': ds_func
}




while True:
    command = input('Введите команду (q - выход): ')
    
    if command == 'q':
        break
        
    func = data.get(command)
    if func:
        func()
    else:
        print('Нет такой команды')
# Out:
# Введите команду (q - выход): p
# Введите номер документа: 123
# Документ не найден в базе.
# Введите команду (q - выход): p
# Введите номер документа: 10006
# Владелец документа: Аристарх Павлов
# Введите команду (q - выход): s
# Введите номер документа: 123
# Документ не найден в базе.
# Введите команду (q - выход): s
# Введите номер документа: 10006
# Документ хранится на полке: 2
# Введите команду (q - выход): l
# № 2207 876234, тип: passport, владелец: Василий Гупкин, полка хранения: 1
# № 11-2, тип: invoice, владелец: Геннадий Покемонов, полка хранения: 1
# № 10006, тип: insurance, владелец: Аристарх Павлов, полка хранения: 2
# Введите команду (q - выход): as
# Введите номер полки: 1
# Такая полка уже существует. Текущий перечень полок: 1,2,3
# Введите команду (q - выход): as
# Введите номер полки: 5
# Полка добавлена. Текущий перечень полок: 1,2,3,5
# Введите команду (q - выход): as
# Введите номер полки: 5
# Такая полка уже существует. Текущий перечень полок: 1,2,3
# ...
